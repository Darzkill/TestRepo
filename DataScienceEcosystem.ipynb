# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# ## Data Science Tools and Ecosystem

# %% [markdown]
# ### Introducción
#
# En este cuaderno, se resumen las herramientas y ecosistemas de ciencia de datos.

# %% [markdown]
# #### Los lenguajes más utilizados en ciencia de datos son:
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# #### Bibliotecas de Ciencia de Datos
# Algunas bibliotecas clave para la ciencia de datos incluyen:
#
# Pandas: para manipulación y análisis de datos.
#
# NumPy: para cálculos numéricos.
#
# Matplotlib: para visualización de datos.
#
# Scikit-learn: para aprendizaje automático.
#
# TensorFlow: para aprendizaje profundo.

# %% [markdown]
# #### Herramientas de Ciencia de Datos
#
# | Herramienta| Descripción|
# |:------------------|:---------------------------------------------|
# | Jupyter Notebook |Entorno interactivo para código y documentación|
# | GitHub           |Plataforma para control de versiones y colaboración|
# | RStudio          |Entorno de desarrollo para R|
# | Apache Spark     |Motor para procesamiento de datos a gran escala|
# | Tableau          |Herramienta para visualización de datos interactiva|

# %% [markdown]
# ## Ejemplos de Expresiones Aritméticas
# Las expresiones aritméticas son esenciales en programación. Ejemplos:
# - Suma: `5 + 3 = 8`
# - Multiplicación: `4 * 6 = 24`
# - División: `15 / 3 = 5`

# %%
print("Esta es una expresión aritmética simple para multiplicar y luego sumar enteros")
(3*4)+5
# Out:
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros
# 17

# %%
# Ejercicio 9: Convertir minutos en horas
minutos = 200
horas = minutos / 60
print("Esto convertirá 200 minutos a horas dividiendo por 6")
print(f"{minutos} minutos equivalen a {horas:.2f} horas")
# Out:
# Esto convertirá 200 minutos a horas dividiendo por 6
# 200 minutos equivalen a 3.33 horas

# %%
# Ejercicio 10: Lista de Objetivos
print("Listar lenguajes populares para Ciencia de Datos")
objetivos = [
    "Aprender lenguajes de programación para ciencia de datos",
    "Dominar bibliotecas como Pandas y NumPy",
    "Utilizar herramientas como Jupyter y GitHub",
    "Implementar operaciones aritméticas en Python",
    "Compartir proyectos en GitHub"
]
for i, objetivo in enumerate(objetivos, 1):
    print(f"Objetivo {i}: {objetivo}")
# Out:
# Listar lenguajes populares para Ciencia de Datos
# Objetivo 1: Aprender lenguajes de programación para ciencia de datos
# Objetivo 2: Dominar bibliotecas como Pandas y NumPy
# Objetivo 3: Utilizar herramientas como Jupyter y GitHub
# Objetivo 4: Implementar operaciones aritméticas en Python
# Objetivo 5: Compartir proyectos en GitHub

# %% [markdown]
# #### Autor
# Nombre del Autor: Dante Armando Ramos Zuñiga
